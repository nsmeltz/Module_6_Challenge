# %% [markdown]
# # Deliverable 1: API call to get OpenWeatherMap data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. Randomly generate a list of 2000 lat/longs

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#print(coordinates)

# %% [markdown]
# ### 2. Get the nearest city using the citipy module.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the city names
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %% [markdown]
# ### 3. Perform an API call with the OpenWeatherMap

# %%
# Import requests module
import requests 

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import API key from the config.py file
from config import weather_key
# URL for OpenWeatherMap with units set to imperail and my API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
# Start the timer
start = time.time()

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description" : city_description 
                         }
                        )

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# End the timer and print out time elapsed
end = time.time()
print ("Time elapsed:", end - start)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | umm lajj
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | luba
# Processing Record 6 of Set 1 | abengourou
# Processing Record 7 of Set 1 | kisangani
# Processing Record 8 of Set 1 | salinas
# Processing Record 9 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 1 | heishan
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | asau
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | oistins
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | saint-francois
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | lasa
# Processing Record 24 of Set 1 | barabai
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | blyznyuky
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | acapulco
# Processing Record 32 of Set 1 | sangar
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | nouadhibou
# Processing Record 35 of Set 1 | kralendijk
# Processing Record 36 of Set 1 | york
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | yining
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | port lincoln
# Processing Record 41 of Set 1 | treinta y tres
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | tete
# Processing Record 47 of Set 1 | port blair
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | puerto guzman
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | erenhot
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | mwense
# Processing Record 4 of Set 2 | khandbari
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | bento goncalves
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | lorengau
# Processing Record 10 of Set 2 | iquitos
# Processing Record 11 of Set 2 | tolmin
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | yuzhno-sukhokumsk
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | grand gaube
# Processing Record 19 of Set 2 | springbok
# Processing Record 20 of Set 2 | monticello
# Processing Record 21 of Set 2 | minas de barroteran
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | copiapo
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | islamkot
# Processing Record 27 of Set 2 | faya
# Processing Record 28 of Set 2 | chuy
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | meghraj
# Processing Record 32 of Set 2 | namatanai
# Processing Record 33 of Set 2 | skelleftea
# Processing Record 34 of Set 2 | saint-louis
# Processing Record 35 of Set 2 | sal rei
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | feuchtwangen
# Processing Record 39 of Set 2 | helong
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | bubaque
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | riyadh
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | kibaya
# Processing Record 50 of Set 2 | kruisfontein
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 3 | alofi
# Processing Record 4 of Set 3 | maraba
# Processing Record 5 of Set 3 | karratha
# Processing Record 6 of Set 3 | yumen
# Processing Record 7 of Set 3 | sembakung
# Processing Record 8 of Set 3 | honningsvag
# Processing Record 9 of Set 3 | broome
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | cap malheureux
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | kaeo
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | codrington
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 3 | svetlyy
# Processing Record 23 of Set 3 | tezu
# Processing Record 24 of Set 3 | juneau
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | norsup
# Processing Record 27 of Set 3 | ust-maya
# Processing Record 28 of Set 3 | berlevag
# Processing Record 29 of Set 3 | kushmurun
# Processing Record 30 of Set 3 | cururupu
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | moerai
# Processing Record 34 of Set 3 | najran
# Processing Record 35 of Set 3 | carmen
# Processing Record 36 of Set 3 | kaseda
# Processing Record 37 of Set 3 | enna
# Processing Record 38 of Set 3 | narsaq
# Processing Record 39 of Set 3 | ponnampet
# Processing Record 40 of Set 3 | quelimane
# Processing Record 41 of Set 3 | huangmei
# Processing Record 42 of Set 3 | ogbomosho
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | orizona
# Processing Record 45 of Set 3 | umm kaddadah
# Processing Record 46 of Set 3 | atasu
# Processing Record 47 of Set 3 | japura
# Processing Record 48 of Set 3 | tagdangua
# City not found. Skipping...
# Processing Record 49 of Set 3 | fairhope
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | haines junction
# Processing Record 2 of Set 4 | necochea
# Processing Record 3 of Set 4 | mamlyutka
# Processing Record 4 of Set 4 | belle fourche
# Processing Record 5 of Set 4 | san quintin
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | te anau
# Processing Record 11 of Set 4 | kupang
# Processing Record 12 of Set 4 | dudinka
# Processing Record 13 of Set 4 | araouane
# Processing Record 14 of Set 4 | healdsburg
# Processing Record 15 of Set 4 | piacabucu
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | port-gentil
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | salvador
# Processing Record 23 of Set 4 | kaura namoda
# Processing Record 24 of Set 4 | lixourion
# Processing Record 25 of Set 4 | valle de guadalupe
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | kirovo-chepetsk
# Processing Record 28 of Set 4 | tommot
# Processing Record 29 of Set 4 | lavrentiya
# Processing Record 30 of Set 4 | zyryanka
# Processing Record 31 of Set 4 | bochnia
# Processing Record 32 of Set 4 | dikson
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | vestmanna
# Processing Record 36 of Set 4 | maler kotla
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | anadyr
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | hovd
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | ostersund
# Processing Record 43 of Set 4 | pilao arcado
# City not found. Skipping...
# Processing Record 44 of Set 4 | hasaki
# Processing Record 45 of Set 4 | rocha
# Processing Record 46 of Set 4 | osakarovka
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | mahibadhoo
# Processing Record 49 of Set 4 | windhoek
# Processing Record 50 of Set 4 | hami
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | owando
# Processing Record 3 of Set 5 | ardakan
# Processing Record 4 of Set 5 | chingirlau
# Processing Record 5 of Set 5 | ketchikan
# Processing Record 6 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | nizwa
# Processing Record 10 of Set 5 | ostrovnoy
# Processing Record 11 of Set 5 | ekuvukeni
# Processing Record 12 of Set 5 | beruwala
# Processing Record 13 of Set 5 | bardiyah
# Processing Record 14 of Set 5 | bud
# Processing Record 15 of Set 5 | fukue
# Processing Record 16 of Set 5 | bemidji
# Processing Record 17 of Set 5 | santiago del estero
# Processing Record 18 of Set 5 | craig
# Processing Record 19 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | quatre cocos
# Processing Record 22 of Set 5 | independencia
# Processing Record 23 of Set 5 | polunochnoye
# Processing Record 24 of Set 5 | lagos
# Processing Record 25 of Set 5 | yen bai
# Processing Record 26 of Set 5 | castro
# Processing Record 27 of Set 5 | ojinaga
# Processing Record 28 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 5 | porto novo
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 5 | maceio
# Processing Record 33 of Set 5 | tuktoyaktuk
# Processing Record 34 of Set 5 | jasper
# Processing Record 35 of Set 5 | takoradi
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | laguna
# Processing Record 38 of Set 5 | octeville
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | roebourne
# Processing Record 41 of Set 5 | tiksi
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | chekhov
# Processing Record 44 of Set 5 | lima
# Processing Record 45 of Set 5 | chokurdakh
# Processing Record 46 of Set 5 | beyneu
# Processing Record 47 of Set 5 | high level
# Processing Record 48 of Set 5 | zhigansk
# Processing Record 49 of Set 5 | puerto colombia
# Processing Record 50 of Set 5 | leninsk
# Processing Record 1 of Set 6 | menongue
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | am timan
# Processing Record 4 of Set 6 | chany
# Processing Record 5 of Set 6 | port hedland
# Processing Record 6 of Set 6 | chamonix-mont-blanc
# Processing Record 7 of Set 6 | saint-joseph
# Processing Record 8 of Set 6 | tiznit
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | fenelon falls
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | nizhniy tsasuchey
# Processing Record 14 of Set 6 | storebo
# Processing Record 15 of Set 6 | tilichiki
# Processing Record 16 of Set 6 | touros
# Processing Record 17 of Set 6 | sarakhs
# Processing Record 18 of Set 6 | fairbanks
# Processing Record 19 of Set 6 | izumo
# Processing Record 20 of Set 6 | picayune
# Processing Record 21 of Set 6 | mahebourg
# Processing Record 22 of Set 6 | nanchang
# Processing Record 23 of Set 6 | cabra
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | maningrida
# Processing Record 26 of Set 6 | hervey bay
# Processing Record 27 of Set 6 | lambarene
# Processing Record 28 of Set 6 | coihaique
# Processing Record 29 of Set 6 | bowen
# Processing Record 30 of Set 6 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 31 of Set 6 | qaqortoq
# Processing Record 32 of Set 6 | malanje
# Processing Record 33 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 6 | fortuna
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | tuatapere
# Processing Record 37 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 6 | olinda
# Processing Record 40 of Set 6 | byron bay
# Processing Record 41 of Set 6 | ossora
# Processing Record 42 of Set 6 | sorong
# Processing Record 43 of Set 6 | tabou
# Processing Record 44 of Set 6 | galesong
# Processing Record 45 of Set 6 | aklavik
# Processing Record 46 of Set 6 | three hills
# Processing Record 47 of Set 6 | boddam
# Processing Record 48 of Set 6 | tahta
# Processing Record 49 of Set 6 | airai
# Processing Record 50 of Set 6 | gazanjyk
# Processing Record 1 of Set 7 | kirakira
# Processing Record 2 of Set 7 | cherskiy
# Processing Record 3 of Set 7 | morondava
# Processing Record 4 of Set 7 | leshukonskoye
# Processing Record 5 of Set 7 | diksmuide
# Processing Record 6 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 7 | soyo
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | wiarton
# Processing Record 10 of Set 7 | sistranda
# Processing Record 11 of Set 7 | bonthe
# Processing Record 12 of Set 7 | itoman
# Processing Record 13 of Set 7 | vila velha
# Processing Record 14 of Set 7 | lipin bor
# Processing Record 15 of Set 7 | omagari
# Processing Record 16 of Set 7 | tigil
# Processing Record 17 of Set 7 | santa elena
# Processing Record 18 of Set 7 | congonhas
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | rio gallegos
# Processing Record 21 of Set 7 | kichera
# Processing Record 22 of Set 7 | malm
# Processing Record 23 of Set 7 | maxixe
# Processing Record 24 of Set 7 | sovetskaya gavan
# Processing Record 25 of Set 7 | hambantota
# Processing Record 26 of Set 7 | thinadhoo
# Processing Record 27 of Set 7 | vilyuysk
# Processing Record 28 of Set 7 | dalby
# Processing Record 29 of Set 7 | vestmannaeyjar
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | thunder bay
# Processing Record 32 of Set 7 | lingao
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | svobodnyy
# Processing Record 35 of Set 7 | sterling
# Processing Record 36 of Set 7 | sisimiut
# Processing Record 37 of Set 7 | otane
# Processing Record 38 of Set 7 | whittlesea
# Processing Record 39 of Set 7 | santa isabel
# Processing Record 40 of Set 7 | ebejico
# Processing Record 41 of Set 7 | leerdam
# Processing Record 42 of Set 7 | chapleau
# Processing Record 43 of Set 7 | yenangyaung
# Processing Record 44 of Set 7 | nalut
# Processing Record 45 of Set 7 | saint george
# Processing Record 46 of Set 7 | mlalo
# Processing Record 47 of Set 7 | vanimo
# Processing Record 48 of Set 7 | praia
# Processing Record 49 of Set 7 | cleveland
# Processing Record 50 of Set 7 | borama
# City not found. Skipping...
# Processing Record 1 of Set 8 | mopti
# Processing Record 2 of Set 8 | belaya gora
# Processing Record 3 of Set 8 | kadhan
# Processing Record 4 of Set 8 | flinders
# Processing Record 5 of Set 8 | daru
# Processing Record 6 of Set 8 | beinamar
# Processing Record 7 of Set 8 | bilibino
# Processing Record 8 of Set 8 | buala
# Processing Record 9 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 8 | sola
# Processing Record 11 of Set 8 | christchurch
# Processing Record 12 of Set 8 | komsomolskiy
# Processing Record 13 of Set 8 | berja
# Processing Record 14 of Set 8 | severo-kurilsk
# Processing Record 15 of Set 8 | sept-iles
# Processing Record 16 of Set 8 | half moon bay
# Processing Record 17 of Set 8 | taltal
# Processing Record 18 of Set 8 | antofagasta
# Processing Record 19 of Set 8 | lazaro cardenas
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 8 | kushiro
# Processing Record 23 of Set 8 | baiyin
# Processing Record 24 of Set 8 | lalsot
# Processing Record 25 of Set 8 | mbengwi
# Processing Record 26 of Set 8 | rio grande
# Processing Record 27 of Set 8 | poum
# Processing Record 28 of Set 8 | matara
# Processing Record 29 of Set 8 | fort-shevchenko
# Processing Record 30 of Set 8 | savannah bight
# Processing Record 31 of Set 8 | singaparna
# Processing Record 32 of Set 8 | bilma
# Processing Record 33 of Set 8 | tarauaca
# Processing Record 34 of Set 8 | san cristobal
# Processing Record 35 of Set 8 | buraydah
# Processing Record 36 of Set 8 | karasjok
# Processing Record 37 of Set 8 | ayan
# Processing Record 38 of Set 8 | amahai
# Processing Record 39 of Set 8 | rio de janeiro
# Processing Record 40 of Set 8 | san luis
# Processing Record 41 of Set 8 | ingham
# Processing Record 42 of Set 8 | turukhansk
# Processing Record 43 of Set 8 | indiaroba
# Processing Record 44 of Set 8 | rafai
# Processing Record 45 of Set 8 | dubuque
# Processing Record 46 of Set 8 | mehamn
# Processing Record 47 of Set 8 | lagoa
# Processing Record 48 of Set 8 | opuwo
# Processing Record 49 of Set 8 | rudnogorsk
# Processing Record 50 of Set 8 | khani
# Processing Record 1 of Set 9 | geraldton
# Processing Record 2 of Set 9 | huambo
# Processing Record 3 of Set 9 | manaure
# Processing Record 4 of Set 9 | svetlaya
# Processing Record 5 of Set 9 | san policarpo
# Processing Record 6 of Set 9 | flin flon
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | tartagal
# Processing Record 9 of Set 9 | cockburn town
# Processing Record 10 of Set 9 | sao gabriel da cachoeira
# Processing Record 11 of Set 9 | talnakh
# Processing Record 12 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 9 | puerto escondido
# Processing Record 14 of Set 9 | saint anthony
# Processing Record 15 of Set 9 | port augusta
# Processing Record 16 of Set 9 | altamira
# Processing Record 17 of Set 9 | shikohabad
# Processing Record 18 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 19 of Set 9 | masvingo
# Processing Record 20 of Set 9 | halifax
# Processing Record 21 of Set 9 | srednekolymsk
# Processing Record 22 of Set 9 | pitimbu
# Processing Record 23 of Set 9 | hit
# Processing Record 24 of Set 9 | linxia
# Processing Record 25 of Set 9 | meadow lake
# Processing Record 26 of Set 9 | boguchany
# Processing Record 27 of Set 9 | varkaus
# Processing Record 28 of Set 9 | kroya
# Processing Record 29 of Set 9 | marquette
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 9 | luanda
# Processing Record 33 of Set 9 | nacala
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | ramanuj ganj
# Processing Record 36 of Set 9 | guiratinga
# Processing Record 37 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 9 | plouzane
# Processing Record 39 of Set 9 | winton
# Processing Record 40 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 9 | soe
# Processing Record 42 of Set 9 | chernyshevskiy
# Processing Record 43 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 9 | todos santos
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | marzuq
# Processing Record 47 of Set 9 | arrecife
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | spokane
# Processing Record 50 of Set 9 | ormara
# Processing Record 1 of Set 10 | mackay
# Processing Record 2 of Set 10 | chiang rai
# Processing Record 3 of Set 10 | acaxochitlan
# Processing Record 4 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | mao
# Processing Record 6 of Set 10 | margate
# Processing Record 7 of Set 10 | zanjan
# Processing Record 8 of Set 10 | toktogul
# Processing Record 9 of Set 10 | lethem
# Processing Record 10 of Set 10 | vardo
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | umea
# Processing Record 13 of Set 10 | son la
# Processing Record 14 of Set 10 | sinnamary
# Processing Record 15 of Set 10 | amga
# Processing Record 16 of Set 10 | pekalongan
# Processing Record 17 of Set 10 | swan river
# Processing Record 18 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 10 | cuenca
# Processing Record 20 of Set 10 | muslyumovo
# Processing Record 21 of Set 10 | villazon
# Processing Record 22 of Set 10 | arkhangelsk
# Processing Record 23 of Set 10 | wharton
# Processing Record 24 of Set 10 | sungaipenuh
# Processing Record 25 of Set 10 | tucupita
# Processing Record 26 of Set 10 | havre-saint-pierre
# Processing Record 27 of Set 10 | camacha
# Processing Record 28 of Set 10 | ekangala
# Processing Record 29 of Set 10 | college
# Processing Record 30 of Set 10 | basco
# Processing Record 31 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 10 | nurota
# Processing Record 34 of Set 10 | ilebo
# Processing Record 35 of Set 10 | jingdezhen
# Processing Record 36 of Set 10 | cordoba
# Processing Record 37 of Set 10 | neuquen
# Processing Record 38 of Set 10 | harper
# Processing Record 39 of Set 10 | catuday
# Processing Record 40 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 10 | shimoda
# Processing Record 42 of Set 10 | sasykoli
# Processing Record 43 of Set 10 | dzaoudzi
# Processing Record 44 of Set 10 | carlagan
# Processing Record 45 of Set 10 | calama
# Processing Record 46 of Set 10 | miri
# Processing Record 47 of Set 10 | seaford
# Processing Record 48 of Set 10 | ulladulla
# Processing Record 49 of Set 10 | muros
# Processing Record 50 of Set 10 | gat
# Processing Record 1 of Set 11 | dubbo
# Processing Record 2 of Set 11 | moron
# Processing Record 3 of Set 11 | manokwari
# Processing Record 4 of Set 11 | leningradskiy
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 11 | zatoka
# Processing Record 8 of Set 11 | trenggalek
# Processing Record 9 of Set 11 | selma
# Processing Record 10 of Set 11 | brainerd
# Processing Record 11 of Set 11 | esperance
# Processing Record 12 of Set 11 | manoel urbano
# Processing Record 13 of Set 11 | krasnoselkup
# Processing Record 14 of Set 11 | sete lagoas
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | murgab
# Processing Record 17 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 11 | gogrial
# Processing Record 19 of Set 11 | uberaba
# Processing Record 20 of Set 11 | energeticheskiy
# Processing Record 21 of Set 11 | horsham
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | ismailia
# Processing Record 24 of Set 11 | mont-de-marsan
# Processing Record 25 of Set 11 | stoughton
# Processing Record 26 of Set 11 | port macquarie
# Processing Record 27 of Set 11 | namibe
# Processing Record 28 of Set 11 | ratnagiri
# Processing Record 29 of Set 11 | the valley
# Processing Record 30 of Set 11 | payo
# Processing Record 31 of Set 11 | guerrero negro
# Processing Record 32 of Set 11 | kiama
# Processing Record 33 of Set 11 | ayotzingo
# City not found. Skipping...
# Processing Record 34 of Set 11 | xuddur
# Processing Record 35 of Set 11 | powell river
# Processing Record 36 of Set 11 | ankpa
# Processing Record 37 of Set 11 | kysyl-syr
# Processing Record 38 of Set 11 | miramar
# Processing Record 39 of Set 11 | luwero
# Processing Record 40 of Set 11 | broken hill
# Processing Record 41 of Set 11 | talas
# Processing Record 42 of Set 11 | marrakesh
# Processing Record 43 of Set 11 | channel-port aux basques
# Processing Record 44 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 11 | dodan
# Processing Record 46 of Set 11 | vigrestad
# Processing Record 47 of Set 11 | belmonte
# Processing Record 48 of Set 11 | bambanglipuro
# Processing Record 49 of Set 11 | lengshuitan
# Processing Record 50 of Set 11 | henties bay
# Processing Record 1 of Set 12 | hachinohe
# Processing Record 2 of Set 12 | siparia
# Processing Record 3 of Set 12 | san luis rio colorado
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | evensk
# Processing Record 6 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 12 | dawlatabad
# Processing Record 8 of Set 12 | pangody
# Processing Record 9 of Set 12 | kodinsk
# Processing Record 10 of Set 12 | aksu
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | port said
# Processing Record 13 of Set 12 | kampene
# Processing Record 14 of Set 12 | teguise
# Processing Record 15 of Set 12 | yaan
# Processing Record 16 of Set 12 | mount gambier
# Processing Record 17 of Set 12 | hirara
# Processing Record 18 of Set 12 | talcahuano
# Processing Record 19 of Set 12 | pingliang
# Processing Record 20 of Set 12 | tavrichanka
# Processing Record 21 of Set 12 | palmer
# Processing Record 22 of Set 12 | kunda
# Processing Record 23 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 12 | salalah
# Processing Record 25 of Set 12 | barra
# Processing Record 26 of Set 12 | kampong thum
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | yarada
# Processing Record 29 of Set 12 | bradeni
# Processing Record 30 of Set 12 | visnes
# Processing Record 31 of Set 12 | bosansko grahovo
# Processing Record 32 of Set 12 | neepawa
# Processing Record 33 of Set 12 | bakchar
# Processing Record 34 of Set 12 | sur
# Processing Record 35 of Set 12 | hauterive
# Processing Record 36 of Set 12 | popondetta
# Processing Record 37 of Set 12 | nemuro
# Processing Record 38 of Set 12 | hay river
# Processing Record 39 of Set 12 | palma del rio
# Processing Record 40 of Set 12 | san ignacio
# Processing Record 41 of Set 12 | tocopilla
# Processing Record 42 of Set 12 | valparaiso
# Processing Record 43 of Set 12 | vysokogornyy
# Processing Record 44 of Set 12 | mugur-aksy
# Processing Record 45 of Set 12 | poya
# Processing Record 46 of Set 12 | erzin
# Processing Record 47 of Set 12 | dolna banjica
# Processing Record 48 of Set 12 | kodino
# Processing Record 49 of Set 12 | luena
# Processing Record 50 of Set 12 | altay
# Processing Record 1 of Set 13 | zhezkazgan
# Processing Record 2 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 13 | beringovskiy
# Processing Record 4 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 13 | perth
# Processing Record 6 of Set 13 | coquimbo
# Processing Record 7 of Set 13 | port pirie
# Processing Record 8 of Set 13 | wahiawa
# Processing Record 9 of Set 13 | les cayes
# Processing Record 10 of Set 13 | saryozek
# Processing Record 11 of Set 13 | vieques
# Processing Record 12 of Set 13 | igarka
# Processing Record 13 of Set 13 | jalpan
# Processing Record 14 of Set 13 | mount isa
# Processing Record 15 of Set 13 | kavaratti
# Processing Record 16 of Set 13 | omboue
# Processing Record 17 of Set 13 | aykhal
# Processing Record 18 of Set 13 | ballina
# Processing Record 19 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 20 of Set 13 | dawson creek
# Processing Record 21 of Set 13 | penha
# Processing Record 22 of Set 13 | srandakan
# Processing Record 23 of Set 13 | zhanakorgan
# Processing Record 24 of Set 13 | pangai
# Processing Record 25 of Set 13 | rudbar
# Processing Record 26 of Set 13 | kuytun
# Processing Record 27 of Set 13 | swan hill
# Processing Record 28 of Set 13 | fort nelson
# Processing Record 29 of Set 13 | constitucion
# Processing Record 30 of Set 13 | arlit
# Processing Record 31 of Set 13 | katsuura
# Processing Record 32 of Set 13 | uvat
# Processing Record 33 of Set 13 | goure
# Processing Record 34 of Set 13 | shakawe
# Processing Record 35 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 13 | imbituba
# Processing Record 37 of Set 13 | caucaia
# Processing Record 38 of Set 13 | navahrudak
# Processing Record 39 of Set 13 | khorinsk
# Processing Record 40 of Set 13 | kathu
# Processing Record 41 of Set 13 | krasnoye
# Processing Record 42 of Set 13 | conde
# Processing Record 43 of Set 13 | la palma
# Processing Record 44 of Set 13 | ravels
# Processing Record 45 of Set 13 | krasnyy chikoy
# Processing Record 46 of Set 13 | dyer
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | micoud
# Processing Record 49 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 50 of Set 13 | akyab
# Processing Record 1 of Set 14 | mizdah
# Processing Record 2 of Set 14 | imatra
# Processing Record 3 of Set 14 | safford
# Processing Record 4 of Set 14 | ust-nera
# Processing Record 5 of Set 14 | nador
# Processing Record 6 of Set 14 | bathsheba
# Processing Record 7 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 8 of Set 14 | esmeraldas
# Processing Record 9 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 14 | kashi
# Processing Record 11 of Set 14 | tonantins
# Processing Record 12 of Set 14 | beloha
# Processing Record 13 of Set 14 | anchorage
# Processing Record 14 of Set 14 | peniche
# Processing Record 15 of Set 14 | zhangjiakou
# Processing Record 16 of Set 14 | alta
# Processing Record 17 of Set 14 | ambilobe
# Processing Record 18 of Set 14 | vanavara
# Processing Record 19 of Set 14 | iquique
# Processing Record 20 of Set 14 | ushumun
# Processing Record 21 of Set 14 | omsukchan
# Processing Record 22 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 14 | kurchum
# Processing Record 24 of Set 14 | waycross
# Processing Record 25 of Set 14 | walvis bay
# Processing Record 26 of Set 14 | banda
# Processing Record 27 of Set 14 | yarim
# Processing Record 28 of Set 14 | chifeng
# Processing Record 29 of Set 14 | aswan
# Processing Record 30 of Set 14 | bodden town
# Processing Record 31 of Set 14 | vysokaya gora
# Processing Record 32 of Set 14 | sanming
# Processing Record 33 of Set 14 | abu samrah
# Processing Record 34 of Set 14 | jumla
# Processing Record 35 of Set 14 | santa cruz cabralia
# Processing Record 36 of Set 14 | zhob
# Processing Record 37 of Set 14 | micheweni
# Processing Record 38 of Set 14 | korla
# Processing Record 39 of Set 14 | santa rosa
# Processing Record 40 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 14 | kenai
# Processing Record 42 of Set 14 | rajshahi
# Processing Record 43 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 14 | shingu
# Processing Record 45 of Set 14 | massakory
# Processing Record 46 of Set 14 | pampa
# Processing Record 47 of Set 14 | taylorville
# Processing Record 48 of Set 14 | naze
# Processing Record 49 of Set 14 | mattru
# Processing Record 50 of Set 14 | lata
# Processing Record 1 of Set 15 | san jeronimo
# Processing Record 2 of Set 15 | moissala
# Processing Record 3 of Set 15 | gangapur
# Processing Record 4 of Set 15 | sapao
# City not found. Skipping...
# Processing Record 5 of Set 15 | pyu
# Processing Record 6 of Set 15 | marsa matruh
# Processing Record 7 of Set 15 | adrar
# Processing Record 8 of Set 15 | cedar city
# Processing Record 9 of Set 15 | spanish town
# Processing Record 10 of Set 15 | loa janan
# Processing Record 11 of Set 15 | rabo de peixe
# Processing Record 12 of Set 15 | panzhihua
# Processing Record 13 of Set 15 | port moresby
# Processing Record 14 of Set 15 | guymon
# Processing Record 15 of Set 15 | le port
# Processing Record 16 of Set 15 | taoudenni
# Processing Record 17 of Set 15 | hohhot
# Processing Record 18 of Set 15 | rawson
# Processing Record 19 of Set 15 | crotone
# Processing Record 20 of Set 15 | kiratpur
# Processing Record 21 of Set 15 | victor harbor
# Processing Record 22 of Set 15 | hobyo
# Processing Record 23 of Set 15 | doha
# Processing Record 24 of Set 15 | mabay
# Processing Record 25 of Set 15 | chicama
# Processing Record 26 of Set 15 | tarko-sale
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Time elapsed: 1031.219610452652

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# reorder columns
new_col_order = ["City","Country", "Date" , "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Description"]
city_data_df = city_data_df[new_col_order]

# view dataframe
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0      Umm Lajj      SA  2022-01-23 18:23:43  25.0213   37.2685     66.74
# 1        Atuona      PF  2022-01-23 18:15:15  -9.8000 -139.0333     78.49
# 2  Puerto Ayora      EC  2022-01-23 18:16:31  -0.7393  -90.3518     80.56
# 3     Busselton      AU  2022-01-23 18:16:28 -33.6500  115.3333     64.04
# 4          Luba      GQ  2022-01-23 18:23:43   3.4568    8.5547     80.49
# 5    Abengourou      CI  2022-01-23 18:23:43   6.7297   -3.4964     83.68
# 6     Kisangani      CD  2022-01-23 18:23:44   0.5167   25.2000     79.11
# 7       Salinas      US  2022-01-23 18:20:11  36.6777 -121.6555     64.83
# 8       Heishan      CN  2022-01-23 18:23:44  41.6892  122.1128     10.78
# 9     Jamestown      US  2022-01-23 18:14:10  42.0970  -79.2353     26.10
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        58           0       12.35         clear sky
# 1        75          15       17.40        few clouds
# 2        80          93       10.76   overcast clouds
# 3        86          38       13.06  scattered clouds
# 4        77          19        5.95        few clouds
# 5        20           4        1.79         clear sky
# 6        60          95        2.68   overcast clouds
# 7        48           0       16.11         clear sky
# 8        64          47       10.78  scattered clouds
# 9        64         100        5.99              mist

# %%
# Create the output file path & name csv
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Save & Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
